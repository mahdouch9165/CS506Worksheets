# %% [markdown]
# # Worksheet 07
#
# Name:Mahdi Khemakhem
#
# UID: U18251472
#
# ### Topics
#
# - Density-Based Clustering
#
# ### Density-Based Clustering
#
# Follow along with the live coding of the DBScan algorithm.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets

centers = [[1, 1], [-1, -1], [1, -1]]
X, _ = datasets.make_blobs(n_samples=750, centers=centers, cluster_std=0.4,
                            random_state=0)
plt.scatter(X[:,0],X[:,1],s=10, alpha=0.8)
plt.show()

class DBC():

    def __init__(self, dataset, min_pts, epsilon):
        self.dataset = dataset
        self.min_pts = min_pts
        self.epsilon = epsilon
        self.assignments = [0] * len(dataset)

    def distance(self, i, j):
        return np.linalg.norm([self.dataset[i] - self.dataset[j]])

    def get_neighbors(self, i):
        neighborhood = []
        for j in range(len(self.dataset)):
            if self.distance(i,j) <= self.epsilon and i != j:
                neighborhood.append(j)
        return neighborhood

    def is_core(self, i):
        return len(self.get_neighbors(i)) >= self.min_pts
    
    def assign(self, i, cluster_num):
        self.assignments[i] = cluster_num
        neighborhood_queue = self.get_neighbors(i)

        while neighborhood_queue:
            next_candidate = neighborhood_queue.pop(0)
            if self.assignments[next_candidate] != 0:
                continue
            self.assignments[next_candidate] = cluster_num
            if self.is_core(next_candidate):
                self.assignments[next_candidate] = cluster_num
                next_neighborhood = self.get_neighbors(next_candidate)
                neighborhood_queue.append([i for i in next_neighborhood if self.assignments[i] == 0])
        return None

    def dbscan(self):
        """
        returns a list of assignments. The index of the
        assignment should match the index of the data point
        in the dataset.
        """
        
        
        cluster_num = 1
        
        for i in range(len(self.dataset)):
            if self.is_core(i) and self.assignments[i] == 0:
                self.assign(i, cluster_num)
                # cluster_num += 1
                        

        return self.assignments

clustering = DBC(X, 3, .1).dbscan()
colors = np.array([x for x in 'bgrcmykbgrcmykbgrcmykbgrcmyk'])
colors = np.hstack([colors] * 40)
plt.scatter(X[:, 0], X[:, 1], color=colors[clustering].tolist(), s=10, alpha=0.8)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_200144\2555516439.py in <module>
#      63         return self.assignments
#      64
# ---> 65 clustering = DBC(X, 3, .1).dbscan()
#      66 colors = np.array([x for x in 'bgrcmykbgrcmykbgrcmykbgrcmyk'])
#      67 colors = np.hstack([colors] * 40)
#
# ~\AppData\Local\Temp\ipykernel_200144\2555516439.py in dbscan(self)
#      57         for i in range(len(self.dataset)):
#      58             if self.is_core(i) and self.assignments[i] == 0:
# ---> 59                 self.assign(i, cluster_num)
#      60                 # cluster_num += 1
#      61
#
# ~\AppData\Local\Temp\ipykernel_200144\2555516439.py in assign(self, i, cluster_num)
#      36         while neighborhood_queue:
#      37             next_candidate = neighborhood_queue.pop(0)
# ---> 38             if self.assignments[next_candidate] != 0:
#      39                 continue
#      40             self.assignments[next_candidate] = cluster_num
#
# TypeError: list indices must be integers or slices, not list
